# %%
import numpy as np
import time
from data_extract import *
import multiprocessing
import os

# %%
def get_all_files(dir):
    filelist = []

    for root, dirs, files in os.walk(dir):
        for file in files:
            filelist.append(os.path.join(root,file))

    return filelist

# %%
def process_file(db_dir, fname, nworker):
    print("Worker %d is processing file %s" %(nworker, fname))
    compressed_fname = fname[len(db_dir):].split('/')
    run_idx = compressed_fname[1].split('.')
    run_idx = run_idx[0].split('_')
    compressed_fname = compressed_fname[0] + "_" + run_idx[-1] + ".bz2"

    t1 = time.time()
    HDR, data = read_data(fname)
    seqs_v_class_map = segregate_data_into_classes(HDR, data)
    compress_segregated_data(seqs_v_class_map, compressed_fname)
    print("Worker %d is done processing file in %f s" % (nworker, time.time() - t1))

# %%
database_dir = "/home/sweet/1-workdir/eeg001-2017/"
filelist = get_all_files(database_dir)
MAX_NPROCESS = multiprocessing.cpu_count()
print("There are a total of %d files in %s\n" %(len(filelist), database_dir))
print("**********START PROCESSING ALL FILES**********")
print("MAX NUMBER OF PROCESS = %d" %(MAX_NPROCESS))

jobs = []
while len(filelist) > 0:
    for i in range(MAX_NPROCESS):
        if len(filelist) > 0:
            p = multiprocessing.Process(target=process_file, args=(database_dir, filelist.pop(), i))
            jobs.append(p)
            p.start()

    for j in jobs:
        j.join()
# Out:
# There are a total of 300 files in /home/sweet/1-workdir/eeg001-2017/
#
# **********START PROCESSING ALL FILES**********
# MAX NUMBER OF PROCESS = 16
# Worker 0 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run6.gdf
#
# Worker 1 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run4.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run6.gdf in 0.004997 s
# Worker 2 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run3.gdf
#
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run5.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run4.gdf in 0.006307 s
#
#
# Worker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run7.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run3.gdf in 0.006567 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run5.gdf in 0.006372 s
# Worker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run1.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run7.gdf in 0.009723 s
# Worker 6 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run10.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run1.gdf in 0.008927 s
#
# Worker 7 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run2.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run10.gdf in 0.009289 s
#
# Worker 8 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run8.gdfWorker 9 is processing file /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run9.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run2.gdf in 0.014865 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run8.gdf in 0.010106 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run9.gdf in 0.011881 s
#
#
#
# Worker 10 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run2.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run2.gdf in 0.025430 s
# Worker 11 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run4.gdf
#
# Worker 12 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run3.gdf
# Worker 13 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run1.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run4.gdf in 0.037104 s
# Worker 14 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run6.gdf
# Worker 15 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run5.gdf
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run3.gdf in 0.061478 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run1.gdf in 0.110412 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run6.gdf in 0.109933 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run5.gdf in 0.136066 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run5.gdf in 57.940975 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run1.gdf in 58.132137 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run2.gdf in 59.672314 s
#
# Finished segregating data into classes in 2.454750 s
#
# Finished segregating data into classes in 2.307063 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run3.gdf in 60.476692 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run1.gdf in 60.580852 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run2.gdf in 60.884902 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run3.gdf in 61.107576 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run9.gdf in 61.875105 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run5.gdf in 61.642325 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run10.gdf in 62.748821 s
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run6.gdf in 62.803662 s
#
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run4.gdf in 63.371099 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run6.gdf in 63.794106 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run8.gdf in 64.695776 s
#
# Finished segregating data into classes in 5.865816 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S06_MI/motorimagination_subject6_run7.gdf in 66.929387 s
#
# Finished segregating data into classes in 6.469395 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run4.gdf in 68.272615 s
#
# Finished segregating data into classes in 8.444460 s
#
# Finished segregating data into classes in 9.474855 s
#
# Finished segregating data into classes in 9.651120 s
#
# Finished segregating data into classes in 9.780715 s
#
# Finished segregating data into classes in 9.396303 s
#
# Finished segregating data into classes in 11.057773 s
#
# Finished segregating data into classes in 8.289211 s
#
# Finished segregating data into classes in 10.833993 s
#
# Finished segregating data into classes in 10.555141 s
#
# Finished segregating data into classes in 10.045500 s
#
# Finished segregating data into classes in 6.338126 s
# Finished segregating data into classes in 7.991085 s
#
#
# Finished writing 14.89 MB of data to S06_MI_run5 in 18.544940 s
#
# Worker 3 is done processing file in 79.029352 s
# Finished writing 14.87 MB of data to S06_MI_run1 in 18.578854 s
#
# Worker 5 is done processing file in 79.106776 s
# Finished writing 14.91 MB of data to S06_MI_run2 in 14.708956 s
#
# Worker 7 is done processing file in 80.371567 s
# Finished writing 14.87 MB of data to S06_MI_run3 in 10.186388 s
#
# Worker 2 is done processing file in 80.861217 s
# Finished writing 15.07 MB of data to S12_ME_run1 in 11.494960 s
#
# Worker 13 is done processing file in 80.696662 s
# Finished writing 15.14 MB of data to S12_ME_run3 in 13.565103 s
#
# Worker 12 is done processing file in 80.799598 s
# Finished writing 14.89 MB of data to S06_MI_run10 in 9.041914 s
#
# Worker 6 is done processing file in 81.357714 s
# Finished writing 14.89 MB of data to S06_MI_run4 in 7.393046 s
#
# Worker 1 is done processing file in 81.475271 s
# Finished writing 15.12 MB of data to S12_ME_run2 in 10.714900 s
#
# Worker 10 is done processing file in 81.417038 s
# Finished writing 15.28 MB of data to S12_ME_run5 in 9.417902 s
#
# Worker 15 is done processing file in 81.361156 s
# Finished writing 14.91 MB of data to S06_MI_run8 in 8.416390 s
#
# Worker 8 is done processing file in 81.642953 s
# Finished writing 15.32 MB of data to S12_ME_run6 in 7.354583 s
#
# Worker 14 is done processing file in 81.448571 s
# Finished writing 14.86 MB of data to S06_MI_run9 in 8.598381 s
#
# Worker 9 is done processing file in 81.701875 s
# Finished writing 14.83 MB of data to S06_MI_run6 in 8.040117 s
#
# Worker 0 is done processing file in 81.854255 s
# Finished writing 15.24 MB of data to S12_ME_run4 in 6.876316 s
#
# Worker 11 is done processing file in 81.707491 s
# Finished writing 14.89 MB of data to S06_MI_run7 in 7.325915 s
#
# Worker 4 is done processing file in 82.334235 s
# Worker 0 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run10.gdf
# Worker 1 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run7.gdf
# Worker 2 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run9.gdf
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run8.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run10.gdf in 0.012195 s
#
# Worker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run10.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run7.gdf in 0.006945 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run9.gdf in 0.007242 s
#
#
#
# Worker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run8.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run8.gdf in 0.007165 s
# Worker 6 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run2.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run10.gdf in 0.006739 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run8.gdf in 0.007387 s
#
#
#
# Worker 7 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run4.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run2.gdf in 0.012446 s
# Worker 8 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run6.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run4.gdf in 0.019389 s
# Worker 9 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run3.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run6.gdf in 0.023016 s
# Worker 10 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run9.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run3.gdf in 0.027844 s
#
# Worker 11 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run5.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run9.gdf in 0.038298 s
# Worker 12 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run1.gdf
#
# Worker 13 is processing file /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run7.gdf
#
# Worker 14 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run6.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run5.gdf in 0.033356 s
#
#
# Worker 15 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run3.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run7.gdf in 0.058889 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run1.gdf in 0.060872 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run6.gdf in 0.109700 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run3.gdf in 0.123987 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run10.gdf in 58.621258 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run3.gdf in 60.104358 s
#
# Finished segregating data into classes in 2.020256 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run8.gdf in 60.814088 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run9.gdf in 61.532376 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run5.gdf in 62.388001 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run4.gdf in 62.764051 s
#
# Finished segregating data into classes in 2.479582 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run1.gdf in 62.870421 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run2.gdf in 63.809422 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run3.gdf in 63.758662 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run8.gdf in 64.205105 s
# Finished segregating data into classes in 3.359864 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run10.gdf in 64.261346 s
#
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S12_ME/motorexecution_subject12_run7.gdf in 64.586592 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run9.gdf in 64.621784 s
#
# Finished segregating data into classes in 4.374408 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run6.gdf in 66.587520 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run6.gdf in 69.414773 s
#
# Finished segregating data into classes in 7.456109 s
#
# Finished segregating data into classes in 8.168968 s
#
# Finished segregating data into classes in 9.508674 s
#
# Finished segregating data into classes in 8.187559 s
#
# Finished segregating data into classes in 8.841449 s
#
# Finished segregating data into classes in 9.609999 s
#
# Finished segregating data into classes in 9.809793 s
#
# Finished segregating data into classes in 9.434542 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_MI/motorimagination_subject4_run7.gdf in 73.806804 s
#
# Finished segregating data into classes in 9.788890 s
#
# Finished segregating data into classes in 7.842887 s
#
# Finished segregating data into classes in 5.389897 s
#
# Finished segregating data into classes in 2.627079 s
#
# Finished writing 15.36 MB of data to S12_ME_run10 in 18.526136 s
#
# Worker 0 is done processing file in 79.215075 s
# Finished writing 14.99 MB of data to S04_MI_run8 in 16.043894 s
#
# Worker 5 is done processing file in 80.349432 s
# Finished writing 14.57 MB of data to S04_ME_run3 in 17.490964 s
#
# Worker 15 is done processing file in 80.275818 s
# Finished writing 15.35 MB of data to S12_ME_run9 in 15.366554 s
#
# Worker 2 is done processing file in 81.386171 s
# Finished writing 15.20 MB of data to S04_MI_run5 in 11.613889 s
#
# Worker 11 is done processing file in 81.584870 s
# Finished writing 15.24 MB of data to S04_MI_run4 in 10.685918 s
#
# Worker 7 is done processing file in 81.754108 s
# Finished writing 15.28 MB of data to S04_MI_run2 in 8.167458 s
#
# Worker 6 is done processing file in 81.885030 s
# Finished writing 15.00 MB of data to S04_MI_run9 in 8.862212 s
#
# Worker 10 is done processing file in 81.815272 s
# Finished writing 15.04 MB of data to S04_MI_run6 in 7.565460 s
#
# Worker 8 is done processing file in 82.125281 s
# Finished writing 14.58 MB of data to S04_ME_run6 in 6.988420 s
#
# Worker 14 is done processing file in 81.992102 s
# Finished writing 15.28 MB of data to S04_MI_run3 in 8.665110 s
#
# Worker 9 is done processing file in 82.173851 s
# Finished writing 15.03 MB of data to S04_MI_run10 in 9.067121 s
#
# Finished writing 15.34 MB of data to S12_ME_run8 in 8.550287 s
#
# Worker 4 is done processing file in 82.307789 s
# Worker 3 is done processing file in 82.314313 s
# Finished writing 15.32 MB of data to S04_MI_run1 in 9.533994 s
#
# Worker 12 is done processing file in 82.228298 s
# Finished writing 15.35 MB of data to S12_ME_run7 in 8.014157 s
#
# Worker 1 is done processing file in 82.512822 s
# Finished writing 15.02 MB of data to S04_MI_run7 in 6.366376 s
#
# Worker 13 is done processing file in 82.941705 s
# Worker 0 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run9.gdf
#
# Worker 1 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run2.gdfWorker 2 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run8.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run9.gdf in 0.008793 s
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run7.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run2.gdf in 0.007486 s
#
#
#
# Worker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run5.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run8.gdf in 0.006090 s
# Worker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run4.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run7.gdf in 0.009781 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run5.gdf in 0.007923 s
# Worker 6 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run1.gdf
#
# Worker 7 is processing file /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run10.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run4.gdf in 0.010328 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run1.gdf in 0.010511 s
# Worker 8 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run5.gdf
#
# Worker 9 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run1.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run10.gdf in 0.010028 s
#
#
# Worker 10 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run6.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run5.gdf in 0.016222 s
#
#
# Worker 11 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run3.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run1.gdf in 0.021014 s
#
# Worker 12 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run10.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run6.gdf in 0.027440 s
# Worker 13 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run7.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run3.gdf in 0.020798 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run10.gdf in 0.038738 s
# Worker 14 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run2.gdfWorker 15 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run8.gdf
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run7.gdf in 0.035127 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run2.gdf in 0.040439 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run8.gdf in 0.048125 s
#
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run8.gdf in 61.515190 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run9.gdf in 61.682131 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run4.gdf in 63.212568 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run3.gdf in 63.171831 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run1.gdf in 64.454087 s
#
# Finished segregating data into classes in 2.815649 s
#
# Finished segregating data into classes in 3.081452 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run2.gdf in 65.287531 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run5.gdf in 65.747984 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run10.gdf in 65.709538 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run7.gdf in 67.361247 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run10.gdf in 67.477728 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run1.gdf in 67.731218 s
#
# Finished segregating data into classes in 4.644455 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run8.gdf in 69.148687 s
#
# Finished segregating data into classes in 6.225318 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run2.gdf in 69.712444 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S04_ME/motorexecution_subject4_run5.gdf in 70.245835 s
#
# Finished segregating data into classes in 6.572429 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run6.gdf in 71.618400 s
#
# Finished segregating data into classes in 7.220314 s
#
# Finished segregating data into classes in 7.453923 s
#
# Finished segregating data into classes in 7.847558 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run7.gdf in 74.788207 s
#
# Finished segregating data into classes in 7.898248 s
#
# Finished segregating data into classes in 7.856436 s
#
# Finished segregating data into classes in 8.850274 s
#
# Finished segregating data into classes in 7.856167 s
# Finished segregating data into classes in 7.368944 s
#
#
# Finished segregating data into classes in 7.634884 s
#
# Finished segregating data into classes in 6.646637 s
#
# Finished segregating data into classes in 3.810526 s
#
# Finished writing 14.60 MB of data to S04_ME_run9 in 17.909195 s
#
# Worker 0 is done processing file in 82.540614 s
# Finished writing 14.58 MB of data to S04_ME_run8 in 18.170979 s
#
# Worker 2 is done processing file in 82.837396 s
# Finished writing 14.56 MB of data to S04_ME_run4 in 15.684071 s
#
# Worker 5 is done processing file in 83.685193 s
# Finished writing 15.15 MB of data to S11_MI_run3 in 14.399584 s
#
# Worker 11 is done processing file in 84.086904 s
# Finished writing 14.57 MB of data to S04_ME_run1 in 12.910847 s
#
# Worker 6 is done processing file in 84.234751 s
# Finished writing 14.57 MB of data to S04_ME_run2 in 11.768876 s
#
# Worker 1 is done processing file in 84.351744 s
# Finished writing 15.16 MB of data to S11_MI_run1 in 8.633123 s
#
# Worker 9 is done processing file in 84.449502 s
# Finished writing 15.35 MB of data to S11_MI_run10 in 10.999909 s
#
# Worker 12 is done processing file in 84.411867 s
# Finished writing 14.58 MB of data to S04_ME_run7 in 9.178866 s
#
# Worker 3 is done processing file in 84.704129 s
# Finished writing 15.15 MB of data to S11_MI_run5 in 10.967084 s
#
# Worker 8 is done processing file in 84.736384 s
# Finished writing 14.61 MB of data to S04_ME_run10 in 8.458261 s
#
# Worker 7 is done processing file in 84.955745 s
# Finished writing 15.29 MB of data to S11_MI_run8 in 7.737101 s
#
# Worker 15 is done processing file in 84.973431 s
# Finished writing 14.58 MB of data to S04_ME_run5 in 7.291152 s
#
# Worker 4 is done processing file in 85.284795 s
# Finished writing 15.16 MB of data to S11_MI_run2 in 7.900184 s
#
# Worker 14 is done processing file in 85.164291 s
# Finished writing 15.27 MB of data to S11_MI_run6 in 6.865586 s
#
# Worker 10 is done processing file in 85.331393 s
# Finished writing 15.27 MB of data to S11_MI_run7 in 6.606981 s
#
# Worker 13 is done processing file in 85.392035 s
# Worker 0 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run9.gdf
# Worker 1 is processing file /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run4.gdf
# Worker 2 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run3.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run9.gdf in 0.009053 s
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run8.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run4.gdf in 0.007241 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run3.gdf in 0.007730 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run8.gdf in 0.009034 s
#
# Worker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run5.gdfWorker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run7.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run7.gdf in 0.008910 s
# Worker 6 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run10.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run5.gdf in 0.011507 s
# Worker 7 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run2.gdfWorker 10 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run6.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run10.gdf in 0.017431 s
# Worker 11 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run1.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run6.gdf in 0.011210 s
#
# Worker 9 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run9.gdfWorker 12 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run9.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run2.gdf in 0.012483 s
# Worker 13 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run1.gdfWorker 8 is processing file /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run4.gdf
#
#
#
#
#
# Worker 14 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run10.gdf
#
# Worker 15 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run2.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run9.gdf in 0.043204 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run4.gdf in 0.060569 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run1.gdf in 0.066626 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run9.gdf in 0.077561 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run10.gdf in 0.079164 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run2.gdf in 0.073366 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run1.gdf in 0.084640 s
#
#
#
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run9.gdf in 63.698253 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run7.gdf in 64.959095 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S11_MI/motorimagination_subject11_run4.gdf in 65.094387 s
#
# Finished segregating data into classes in 2.360823 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run4.gdf in 66.521805 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run1.gdf in 66.666668 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run3.gdf in 67.036753 s
#
# Finished segregating data into classes in 2.866059 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run9.gdf in 68.030456 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run5.gdf in 68.365158 s
#
# Finished segregating data into classes in 3.454420 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run10.gdf in 68.773821 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run9.gdf in 69.675045 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run2.gdf in 70.210094 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run6.gdf in 70.587083 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run2.gdf in 71.531233 s
#
# Finished segregating data into classes in 6.071847 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run8.gdf in 73.050420 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run1.gdf in 72.982664 s
#
# Finished segregating data into classes in 6.718236 s
#
# Finished segregating data into classes in 7.033542 s
#
# Finished segregating data into classes in 8.493714 s
#
# Finished segregating data into classes in 8.558556 s
#
# Finished segregating data into classes in 9.350209 s
#
# Finished segregating data into classes in 8.838330 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_ME/motorexecution_subject15_run10.gdf in 78.686863 s
#
# Finished segregating data into classes in 8.878884 s
#
# Finished segregating data into classes in 7.697872 s
#
# Finished segregating data into classes in 9.087913 s
#
# Finished segregating data into classes in 7.250820 s
#
# Finished segregating data into classes in 7.599104 s
#
# Finished segregating data into classes in 3.473232 s
#
# Finished writing 15.33 MB of data to S11_MI_run9 in 18.886290 s
#
# Worker 0 is done processing file in 85.035718 s
# Finished writing 15.16 MB of data to S11_MI_run4 in 18.071211 s
#
# Worker 1 is done processing file in 86.133109 s
# Finished writing 14.89 MB of data to S15_ME_run7 in 17.714038 s
#
# Worker 5 is done processing file in 86.251152 s
# Finished writing 14.87 MB of data to S15_ME_run4 in 13.860751 s
#
# Worker 8 is done processing file in 86.660048 s
# Finished writing 14.27 MB of data to S01_ME_run1 in 12.897651 s
#
# Worker 13 is done processing file in 86.851437 s
# Finished writing 14.88 MB of data to S15_ME_run3 in 13.199565 s
#
# Worker 2 is done processing file in 87.076482 s
# Finished writing 14.27 MB of data to S01_ME_run10 in 8.774220 s
#
# Worker 14 is done processing file in 87.071993 s
# Finished writing 14.28 MB of data to S01_ME_run9 in 8.681308 s
#
# Worker 12 is done processing file in 87.303731 s
# Finished writing 14.90 MB of data to S15_ME_run9 in 10.624045 s
#
# Worker 9 is done processing file in 87.358965 s
# Finished writing 14.27 MB of data to S01_ME_run2 in 8.062704 s
#
# Worker 15 is done processing file in 87.493235 s
# Finished writing 14.89 MB of data to S15_ME_run6 in 7.813920 s
#
# Worker 10 is done processing file in 87.700007 s
# Finished writing 14.93 MB of data to S15_ME_run2 in 8.380630 s
#
# Worker 7 is done processing file in 87.756968 s
# Finished writing 14.85 MB of data to S15_ME_run5 in 10.741849 s
#
# Worker 4 is done processing file in 87.818341 s
# Finished writing 14.92 MB of data to S15_ME_run1 in 7.457240 s
#
# Worker 11 is done processing file in 87.850278 s
# Finished writing 14.90 MB of data to S15_ME_run8 in 7.330075 s
#
# Worker 3 is done processing file in 88.098719 s
# Finished writing 14.96 MB of data to S15_ME_run10 in 6.251845 s
#
# Worker 6 is done processing file in 88.560127 s
# Worker 0 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run4.gdf
# Worker 1 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run5.gdf
# Worker 2 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run3.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run4.gdf in 0.008495 s
#
#
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run6.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run5.gdf in 0.006016 s
#
#
#
# Worker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run7.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run3.gdf in 0.007020 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run6.gdf in 0.006914 s
#
# Worker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run8.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run7.gdf in 0.010274 s
#
# Worker 6 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run10.gdf
# Worker 7 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run4.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run8.gdf in 0.009848 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run10.gdf in 0.008937 s
#
#
# Worker 8 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run8.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run4.gdf in 0.012512 s
# Worker 9 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run6.gdf
#
# Worker 10 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run5.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run8.gdf in 0.025597 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run6.gdf in 0.025077 s
#
#
# Worker 11 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run1.gdf
#
# Worker 12 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run7.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run5.gdf in 0.032548 s
#
#
# Worker 13 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run2.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run1.gdf in 0.040209 s
# Worker 14 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run3.gdf
#
#
# Worker 15 is processing file /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run9.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run7.gdf in 0.065574 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run2.gdf in 0.043343 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run3.gdf in 0.077274 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run9.gdf in 0.104774 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run3.gdf in 65.581549 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run5.gdf in 65.754848 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run4.gdf in 65.914445 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run10.gdf in 67.661516 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run4.gdf in 67.725533 s
#
# Finished segregating data into classes in 3.213685 s
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run6.gdf in 68.773176 s
#
#
# Finished segregating data into classes in 3.497198 s
#
# Finished segregating data into classes in 3.694901 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run7.gdf in 69.625056 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run1.gdf in 69.669211 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run8.gdf in 70.374358 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run7.gdf in 70.249491 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run5.gdf in 71.819649 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run8.gdf in 72.343442 s
#
# Finished segregating data into classes in 5.653680 s
#
# Finished segregating data into classes in 6.556535 s
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run9.gdf in 74.091739 s
#
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run6.gdf in 75.007793 s
#
# Finished segregating data into classes in 6.505151 s
#
# Finished segregating data into classes in 7.709419 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run3.gdf in 76.595330 s
#
# Finished segregating data into classes in 7.453353 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S05_MI/motorimagination_subject5_run2.gdf in 77.456392 s
#
# Finished segregating data into classes in 8.432326 s
#
# Finished segregating data into classes in 8.645300 s
# Finished segregating data into classes in 7.158676 s
#
#
# Finished segregating data into classes in 7.853000 s
#
# Finished segregating data into classes in 7.828621 s
#
# Finished segregating data into classes in 7.252751 s
#
# Finished segregating data into classes in 5.815484 s
#
# Finished segregating data into classes in 5.184692 s
#
# Finished writing 14.26 MB of data to S01_ME_run5 in 17.536841 s
#
# Worker 1 is done processing file in 87.066576 s
# Finished writing 14.60 MB of data to S01_ME_run3 in 18.274730 s
#
# Worker 2 is done processing file in 87.148856 s
# Finished writing 14.31 MB of data to S01_ME_run4 in 17.880705 s
#
# Worker 0 is done processing file in 87.381744 s
# Finished writing 15.03 MB of data to S05_MI_run1 in 11.671450 s
#
# Worker 11 is done processing file in 88.028895 s
# Finished writing 15.01 MB of data to S05_MI_run4 in 13.837324 s
#
# Worker 7 is done processing file in 88.337814 s
# Finished writing 14.98 MB of data to S05_MI_run10 in 14.929940 s
#
# Worker 6 is done processing file in 88.434518 s
# Finished writing 14.98 MB of data to S05_MI_run5 in 9.359582 s
#
# Finished writing 14.26 MB of data to S01_ME_run6 in 12.100445 s
# Worker 10 is done processing file in 88.562815 s
# Worker 3 is done processing file in 88.688493 s
#
# Finished writing 14.27 MB of data to S01_ME_run7 in 11.572351 s
#
# Worker 4 is done processing file in 88.754826 s
# Finished writing 14.26 MB of data to S01_ME_run8 in 9.885553 s
#
# Worker 5 is done processing file in 88.782305 s
# Finished writing 14.97 MB of data to S05_MI_run7 in 9.684425 s
#
# Worker 12 is done processing file in 88.766231 s
# Finished writing 14.97 MB of data to S05_MI_run8 in 8.590903 s
#
# Worker 8 is done processing file in 89.087247 s
# Finished writing 14.98 MB of data to S05_MI_run9 in 7.169351 s
#
# Worker 15 is done processing file in 89.331110 s
# Finished writing 15.02 MB of data to S05_MI_run2 in 6.560151 s
#
# Worker 13 is done processing file in 89.415296 s
# Finished writing 15.00 MB of data to S05_MI_run6 in 7.058754 s
#
# Worker 9 is done processing file in 89.556338 s
# Finished writing 15.02 MB of data to S05_MI_run3 in 6.796703 s
#
# Worker 14 is done processing file in 89.560141 s
# Worker 0 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run10.gdf
# Worker 1 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run2.gdf
# Worker 2 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run9.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run10.gdf in 0.008143 s
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run6.gdf
#
# Worker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run7.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run2.gdf in 0.008015 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run9.gdf in 0.005764 s
#
#
#
# Worker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run8.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run6.gdf in 0.005787 s
# Worker 6 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run3.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run7.gdf in 0.010968 s
# Worker 7 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run1.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run8.gdf in 0.008371 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run3.gdf in 0.009632 s
#
#
# Worker 8 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run5.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run1.gdf in 0.011756 s
# Worker 9 is processing file /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run4.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run5.gdf in 0.015186 s
# Worker 10 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run7.gdfWorker 11 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run3.gdf
#
# Worker 12 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run5.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run4.gdf in 0.029115 s
# Worker 13 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run4.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run7.gdf in 0.032441 s
#
#
# Worker 14 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run9.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run3.gdf in 0.031900 s
#
# Worker 15 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run2.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run4.gdf in 0.034319 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run5.gdf in 0.023794 s
#
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run9.gdf in 0.043213 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run2.gdf in 0.080049 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run10.gdf in 66.514127 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run9.gdf in 68.190953 s
#
# Finished segregating data into classes in 2.267699 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run5.gdf in 69.223257 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run6.gdf in 69.937887 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run1.gdf in 70.337765 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run4.gdf in 70.194414 s
#
# Finished segregating data into classes in 2.454174 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run3.gdf in 70.525057 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run4.gdf in 70.948380 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run3.gdf in 71.281712 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run7.gdf in 72.411572 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run2.gdf in 72.682081 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run7.gdf in 73.094614 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run5.gdf in 74.035337 s
#
# Finished segregating data into classes in 6.715088 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run9.gdf in 76.596651 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run2.gdf in 77.098903 s
# Read data of /home/sweet/1-workdir/eeg001-2017/S09_ME/motorexecution_subject9_run8.gdf in 77.373695 s
#
#
# Finished segregating data into classes in 8.177956 s
#
# Finished segregating data into classes in 8.671464 s
#
# Finished segregating data into classes in 8.423681 s
#
# Finished segregating data into classes in 8.969341 s
#
# Finished segregating data into classes in 8.910999 s
#
# Finished segregating data into classes in 8.849770 s
#
# Finished segregating data into classes in 9.889540 s
#
# Finished segregating data into classes in 10.140563 s
#
# Finished segregating data into classes in 10.141385 s
#
# Finished segregating data into classes in 9.519600 s
#
# Finished segregating data into classes in 7.418359 s
#
# Finished segregating data into classes in 7.135319 s
#
# Finished segregating data into classes in 7.101744 s
#
# Finished writing 14.68 MB of data to S09_ME_run10 in 19.136677 s
#
# Worker 0 is done processing file in 87.993135 s
# Finished writing 14.69 MB of data to S09_ME_run9 in 18.567525 s
#
# Worker 2 is done processing file in 89.337128 s
# Finished writing 14.85 MB of data to S09_ME_run5 in 14.162035 s
#
# Worker 8 is done processing file in 90.290185 s
# Finished writing 14.97 MB of data to S09_ME_run1 in 11.077329 s
#
# Worker 7 is done processing file in 90.515767 s
# Finished writing 14.87 MB of data to S08_ME_run3 in 11.335454 s
#
# Worker 11 is done processing file in 90.545954 s
# Finished writing 14.82 MB of data to S08_ME_run4 in 11.449176 s
#
# Worker 13 is done processing file in 90.544322 s
# Finished writing 14.92 MB of data to S09_ME_run4 in 10.781025 s
# Finished writing 14.94 MB of data to S09_ME_run3 in 10.617511 s
#
#
# Worker 6 is done processing file in 90.898715 sWorker 9 is done processing file in 90.843235 s
#
# Finished writing 14.69 MB of data to S09_ME_run6 in 12.683964 s
#
# Worker 3 is done processing file in 90.987502 s
# Finished writing 14.70 MB of data to S09_ME_run7 in 8.669520 s
#
# Worker 4 is done processing file in 91.121004 s
# Finished writing 14.94 MB of data to S09_ME_run2 in 8.233798 s
#
# Worker 1 is done processing file in 91.237757 s
# Finished writing 14.54 MB of data to S08_ME_run9 in 6.960128 s
#
# Worker 14 is done processing file in 91.227306 s
# Finished writing 14.61 MB of data to S08_ME_run7 in 7.985843 s
#
# Worker 10 is done processing file in 91.403422 s
# Finished writing 14.76 MB of data to S08_ME_run5 in 7.711726 s
#
# Worker 12 is done processing file in 91.380660 s
# Finished writing 14.70 MB of data to S09_ME_run8 in 6.950892 s
#
# Worker 5 is done processing file in 91.587077 s
# Finished writing 14.97 MB of data to S08_ME_run2 in 7.031551 s
#
# Worker 15 is done processing file in 91.562399 s
# Worker 0 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run8.gdf
# Worker 1 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run10.gdf
# Worker 2 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run6.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run8.gdf in 0.008532 s
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run1.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run10.gdf in 0.007102 s
#
#
# Worker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S06_ME/motorexecution_subject6_run9.gdf
# Worker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S06_ME/motorexecution_subject6_run1.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run6.gdf in 0.010042 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S08_ME/motorexecution_subject8_run1.gdf in 0.008540 s
#
# Worker 6 is processing file /home/sweet/1-workdir/eeg001-2017/S06_ME/motorexecution_subject6_run4.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S06_ME/motorexecution_subject6_run9.gdf in 0.012310 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S06_ME/motorexecution_subject6_run1.gdf in 0.010321 s
#
#
# Worker 7 is processing file /home/sweet/1-workdir/eeg001-2017/S06_ME/motorexecution_subject6_run7.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S06_ME/motorexecution_subject6_run4.gdf in 0.006339 s
#
#
# Worker 8 is processing file /home/sweet/1-workdir/eeg001-2017/S06_ME/motorexecution_subject6_run3.gdf
# ...
#
#
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run9.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run4.gdf in 0.007694 s
#
# Worker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run1.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run3.gdf in 0.006341 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run9.gdf in 0.006173 s
# Worker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run7.gdf
#
# Worker 6 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run3.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run1.gdf in 0.009991 s
#
# Worker 7 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run8.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run7.gdf in 0.010416 s
#
#
#
# Worker 8 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run9.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run8.gdf in 0.007782 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run3.gdf in 0.010962 s
#
#
#
# Worker 9 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run6.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run9.gdf in 0.011595 s
# Worker 10 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run1.gdf
#
# Worker 11 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run7.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run1.gdf in 0.027688 s
# Worker 12 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run5.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run6.gdf in 0.022728 s
#
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run7.gdf in 0.027359 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run5.gdf in 0.021334 s
# Worker 13 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run4.gdf
#
#
# Worker 14 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run2.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run4.gdf in 0.026650 s
#
# Worker 15 is processing file /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run10.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run2.gdf in 0.058559 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run10.gdf in 0.135522 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run3.gdf in 69.028918 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run4.gdf in 70.566104 s
#
# Finished segregating data into classes in 2.121794 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run1.gdf in 71.501258 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run9.gdf in 71.980542 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run8.gdf in 72.244878 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run5.gdf in 72.791967 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run1.gdf in 73.121778 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run3.gdf in 73.656254 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run9.gdf in 74.134240 s
#
# Finished segregating data into classes in 3.552696 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run7.gdf in 74.812828 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run2.gdf in 74.783024 s
# Finished segregating data into classes in 6.531002 s
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run4.gdf in 77.838049 s
#
#
# Finished segregating data into classes in 7.693773 s
#
# Finished segregating data into classes in 7.706292 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run5.gdf in 80.492060 s
#
# Finished segregating data into classes in 8.644546 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run10.gdf in 81.382559 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S02_MI/motorimagination_subject2_run6.gdf in 82.090660 s
#
# Finished segregating data into classes in 8.502529 s
#
# Finished segregating data into classes in 9.217206 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S10_ME/motorexecution_subject10_run7.gdf in 82.884274 s
#
# Finished segregating data into classes in 8.279197 s
#
# Finished segregating data into classes in 9.405266 s
#
# Finished segregating data into classes in 8.433721 s
#
# Finished segregating data into classes in 3.769062 s
#
# Finished segregating data into classes in 8.682402 s
#
# Finished segregating data into classes in 5.791665 s
#
# Finished segregating data into classes in 7.325327 s
#
# Finished segregating data into classes in 6.138543 s
#
# Finished writing 15.18 MB of data to S10_ME_run3 in 20.433721 s
#
# Worker 2 is done processing file in 91.652319 s
# Finished writing 15.20 MB of data to S10_ME_run4 in 18.232513 s
#
# Worker 1 is done processing file in 92.462193 s
# Finished writing 14.58 MB of data to S02_MI_run9 in 13.261008 s
#
# Worker 8 is done processing file in 93.069378 s
# Finished writing 15.12 MB of data to S10_ME_run1 in 15.002076 s
#
# Worker 4 is done processing file in 93.163886 s
# Finished writing 14.59 MB of data to S02_MI_run7 in 10.075438 s
#
# Worker 11 is done processing file in 93.428802 s
# Finished writing 14.61 MB of data to S02_MI_run8 in 13.467514 s
#
# Worker 7 is done processing file in 93.542463 s
# Finished writing 14.58 MB of data to S02_MI_run3 in 11.331143 s
#
# Worker 6 is done processing file in 93.681481 s
# Finished writing 14.59 MB of data to S02_MI_run2 in 10.223666 s
#
# Worker 14 is done processing file in 93.649360 s
# Finished writing 14.57 MB of data to S02_MI_run1 in 11.271986 s
#
# Worker 10 is done processing file in 93.845464 s
# Finished writing 15.33 MB of data to S10_ME_run9 in 10.493140 s
#
# Worker 3 is done processing file in 94.119351 s
# Finished writing 15.20 MB of data to S10_ME_run5 in 12.561040 s
#
# Worker 0 is done processing file in 94.204455 s
# Finished writing 14.57 MB of data to S02_MI_run4 in 7.434740 s
#
# Worker 13 is done processing file in 94.123942 s
# Finished writing 15.36 MB of data to S10_ME_run7 in 7.730391 s
#
# Worker 5 is done processing file in 94.536177 s
# Finished writing 14.59 MB of data to S02_MI_run5 in 6.463367 s
#
# Worker 12 is done processing file in 94.433641 s
# Finished writing 14.59 MB of data to S02_MI_run10 in 7.085854 s
#
# Worker 15 is done processing file in 94.468255 s
# Finished writing 14.58 MB of data to S02_MI_run6 in 6.656560 s
#
# Worker 9 is done processing file in 95.045374 s
# Worker 0 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run1.gdf
# Worker 1 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run7.gdf
# Worker 2 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run5.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run1.gdf in 0.005311 s
#
#
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run4.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run5.gdf in 0.005172 s
# Worker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run2.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run7.gdf in 0.010382 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run4.gdf in 0.007224 s
# Worker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run8.gdf
#
# Worker 6 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run9.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run2.gdf in 0.011383 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run8.gdf in 0.007860 s
#
#
#
# Worker 7 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run10.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run9.gdf in 0.010384 s
# Worker 8 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run6.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run10.gdf in 0.011176 s
#
#
#
# Worker 9 is processing file /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run3.gdf
# Worker 10 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run7.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run6.gdf in 0.022852 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run3.gdf in 0.014272 s
# Worker 11 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run6.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run7.gdf in 0.017563 s
# Worker 12 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run3.gdf
#
# Worker 13 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run5.gdf
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run6.gdf in 0.033506 s
# Worker 14 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run10.gdf
#
# Worker 15 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run9.gdfRead header of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run3.gdf in 0.056755 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run5.gdf in 0.044332 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run10.gdf in 0.043445 s
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run9.gdf in 0.080504 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run7.gdf in 71.684992 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run5.gdf in 71.868943 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run6.gdf in 72.749300 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run9.gdf in 72.994267 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run3.gdf in 73.840887 s
#
# Finished segregating data into classes in 3.932320 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run10.gdf in 75.671812 s
#
# Finished segregating data into classes in 4.094103 s
#
# Finished segregating data into classes in 4.359825 s
#
# Finished segregating data into classes in 4.950241 s
#
# Finished segregating data into classes in 4.651448 s
#
# Finished segregating data into classes in 3.515395 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run1.gdf in 81.639052 s
#
# Finished segregating data into classes in 1.930095 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run7.gdf in 84.423455 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run2.gdf in 85.724288 s
#
# Finished segregating data into classes in 2.221473 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run9.gdf in 87.122476 s
#
# Finished writing 15.03 MB of data to S15_MI_run7 in 11.353480 s
#
# Worker 10 is done processing file in 87.151977 s
# Finished segregating data into classes in 1.839649 s
#
# Finished writing 14.97 MB of data to S15_MI_run5 in 11.605992 s
# Worker 13 is done processing file in 87.769576 s
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run5.gdf in 88.456836 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run3.gdf in 88.841069 s
# Finished writing 14.97 MB of data to S15_MI_run3 in 10.172662 s
#
#
# Worker 12 is done processing file in 88.870772 s
# Finished segregating data into classes in 1.978013 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run4.gdf in 89.195082 s
#
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run8.gdf in 89.650060 s
#
# Finished writing 15.03 MB of data to S15_MI_run6 in 11.837154 s
#
# Worker 11 is done processing file in 89.705812 s
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run6.gdf in 89.974705 s
#
# Finished writing 15.02 MB of data to S15_MI_run9 in 12.806320 s
#
# Worker 15 is done processing file in 90.436599 s
# Read data of /home/sweet/1-workdir/eeg001-2017/S01_MI/motorimagination_subject1_run10.gdf in 91.244805 s
#
# Finished segregating data into classes in 3.708926 s
#
# Finished segregating data into classes in 3.746556 s
#
# Finished writing 15.05 MB of data to S15_MI_run10 in 13.531667 s
#
# Worker 14 is done processing file in 92.860200 s
# Finished segregating data into classes in 4.659363 s
#
# Finished segregating data into classes in 4.659543 s
#
# Finished segregating data into classes in 3.475742 s
#
# Finished segregating data into classes in 4.919240 s
#
# Finished writing 15.40 MB of data to S01_MI_run1 in 13.182344 s
#
# Worker 0 is done processing file in 96.820222 s
# Finished writing 15.35 MB of data to S01_MI_run7 in 10.860007 s
#
# Worker 1 is done processing file in 97.597748 s
# Finished writing 15.42 MB of data to S01_MI_run2 in 10.330025 s
#
# Worker 4 is done processing file in 98.008233 s
# Finished writing 15.31 MB of data to S01_MI_run9 in 9.045622 s
#
# Worker 6 is done processing file in 98.227649 s
# Finished writing 15.40 MB of data to S01_MI_run5 in 6.573392 s
#
# Worker 2 is done processing file in 98.879719 s
# Finished writing 15.32 MB of data to S01_MI_run8 in 4.624087 s
#
# Worker 5 is done processing file in 99.018051 s
# Finished writing 15.40 MB of data to S01_MI_run4 in 5.285510 s
#
# Worker 3 is done processing file in 99.241344 s
# Finished writing 15.30 MB of data to S01_MI_run10 in 4.394956 s
#
# Worker 7 is done processing file in 99.314704 s
# Finished writing 15.41 MB of data to S01_MI_run3 in 6.812141 s
#
# Worker 9 is done processing file in 99.562236 s
# Finished writing 15.36 MB of data to S01_MI_run6 in 4.861300 s
#
# Worker 8 is done processing file in 99.910657 s
# Worker 0 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run4.gdf
# Worker 1 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run1.gdf
# Worker 2 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run2.gdf
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run1.gdf in 0.006914 s
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run4.gdf in 0.008399 s
#
#
# Read header of /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run2.gdf in 0.007450 s
#
# Worker 3 is processing file /home/sweet/1-workdir/eeg001-2017/S15_MI/motorimagination_subject15_run8.gdfWorker 5 is processing file /home/sweet/1-workdir/eeg001-2017/S11_ME/motorexecution_subject11_run9.gdfWorker 4 is processing file /home/sweet/1-workdir/eeg001-2017/S11_ME/motorexecution_subject11_run3.gdf

# %%
# Out:
# {1: [4, 5, 6]}
