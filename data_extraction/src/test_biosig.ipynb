# %%
import pylab
import numpy
import biosig

# %%
HDR=biosig.sopen('/home/sweet/1-workdir/eeg001-2017/S01_ME/motorexecution_subject1_run1.gdf','r');
#for i in range(HDR.NS):
#    HDR.CHANNEL[i].OnOff = 0
#HDR.CHANNEL[0].OnOff = 1
data = biosig.sread(HDR, HDR.NRec, 0)
# Out:
# Finished reading header
# Finished reading data
# 0

# %%
#biosig.destructHDR(HDR)
pylab.ion()
pylab.plot(data[:,66:])
pylab.show()

# %%
HDR.EVENT.POS
# Out:
# array([ 2561,  2561,  2561,  3585,  5121,  5121,  5121,  6188,  6188,
#         6188,  7212,  8748,  8748,  8748, 10123, 10123, 10123, 11147,
#        12683, 12683, 12683, 13903, 13903, 13903, 14927, 16463, 16463,
#        16463, 17569, 17569, 17569, 18593, 20129, 20129, 20129, 21300,
#        21300, 21300, 22324, 23860], dtype=uint32)

# %%
HDR.EVENT.TYP
# Out:
# array([23860,     0, 23860,     0, 24901,     0, 24901,     0, 24901,
#            0, 25925,     0, 27461,     0, 27461,     0, 27461,     0,
#        28607,     0, 28607,     0, 28607,     0, 29631,     0, 31167,
#            0, 31167,     0, 31167,     0, 32195,     0, 32195,     0,
#        32195,     0, 33219,     0], dtype=uint16)
